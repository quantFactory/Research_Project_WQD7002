# %%
import tensorflow as tf

# %%
# !pip install tensorflow==2.0.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import io
from google.colab import files

# %%
df_uploaded= files.upload()
# Out:
#      <input type="file" id="files-53222231-669c-4021-b20b-ff594c011d01" name="files[]" multiple disabled />
#      <output id="result-53222231-669c-4021-b20b-ff594c011d01">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
df = pd.read_csv(io.BytesIO(df_uploaded['hpq.us.txt']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-ab01e1ebd0ce> in <module>()
# ----> 1 df = pd.read_csv(io.BytesIO(df_uploaded['hpq.us.txt']))
#
# KeyError: 'hpq.us.txt'
